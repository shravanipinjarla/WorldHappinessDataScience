# %%
pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np

# %%
fifteenth = "../Resources/2015.csv"
sixteenth = "../Resources/2016.csv"
seventeenth = "../Resources/2017.csv"
eighteenth = "../Resources/2018.csv"
nineteenth = "../Resources/2019.csv"

fifteenth_data = pd.read_csv(fifteenth)
sixteenth_data = pd.read_csv(sixteenth)
seventeenth_data = pd.read_csv(seventeenth)
eighteenth_data = pd.read_csv(eighteenth)
nineteenth_data = pd.read_csv(nineteenth)

fif_df = pd.DataFrame(fifteenth_data)
six_df = pd.DataFrame(sixteenth_data)
sev_df = pd.DataFrame(seventeenth_data)
eight_df = pd.DataFrame(eighteenth_data)
nine_df = pd.DataFrame(nineteenth_data)

# %%
x = fif_df['Happiness Score']
y = fif_df['Freedom']

fig, ax = plt.subplots()

ax.scatter(x, y)

ax.set_title("Happiness Score and Freedom Relationship 2015")
ax.set_xlabel("Happiness Score")
ax.set_ylabel("Freedom")

slope, intercept, r_value, p_value, std_err = linregress(x, y)
line = slope * x + intercept
ax.plot(x, line, color='r')

r_squared_5 = r_value ** 2
ax.text(0.05, 0.95, f"R-squared = {r_squared:.3f}", transform=ax.transAxes)

plt.show()

fig.savefig('Freedoms_2015.png', dpi=300, bbox_inches='tight')

# %%
x = six_df['Happiness Score']
y = six_df['Freedom']

fig, ax = plt.subplots()

ax.scatter(x, y)

ax.set_title("Happiness Score and Freedom Relationship 2016")
ax.set_xlabel("Happiness Score")
ax.set_ylabel("Freedom")

slope, intercept, r_value, p_value, std_err = linregress(x, y)
line = slope * x + intercept
ax.plot(x, line, color='r')

r_squared_6 = r_value ** 2
ax.text(0.05, 0.95, f"R-squared = {r_squared:.3f}", transform=ax.transAxes)

plt.show()

fig.savefig('Freedoms_2016.png', dpi=300, bbox_inches='tight')

# %%
x = sev_df['Happiness.Rank']
y = sev_df['Freedom']

fig, ax = plt.subplots()

ax.scatter(x, y)

ax.set_title("Happiness Score and Freedom Relationship 2017")
ax.set_xlabel("Happiness Score")
ax.set_ylabel("Freedom")

slope, intercept, r_value, p_value, std_err = linregress(x, y)
line = slope * x + intercept
ax.plot(x, line, color='r')

r_squared_7 = r_value ** 2
ax.text(0.05, 0.95, f"R-squared = {r_squared:.3f}", transform=ax.transAxes)

plt.show()

fig.savefig('Freedoms_2017.png', dpi=300, bbox_inches='tight')

# %%
x = eight_df['Score']
y = eight_df['Freedom to make life choices']

fig, ax = plt.subplots()

ax.scatter(x, y)

ax.set_title("Happiness Score and Freedom Relationship 2018")
ax.set_xlabel("Happiness Score")
ax.set_ylabel("Freedom")

slope, intercept, r_value, p_value, std_err = linregress(x, y)
line = slope * x + intercept
ax.plot(x, line, color='r')

r_squared_8 = r_value ** 2
ax.text(0.05, 0.95, f"R-squared = {r_squared:.3f}", transform=ax.transAxes)

plt.show()

fig.savefig('Freedoms_2018.png', dpi=300, bbox_inches='tight')

# %%
x = nine_df['Score']
y = nine_df['Freedom to make life choices']

fig, ax = plt.subplots()

ax.scatter(x, y)

ax.set_title("Happiness Score and Freedom Relationship 2019")
ax.set_xlabel("Happiness Score")
ax.set_ylabel("Freedom")

slope, intercept, r_value, p_value, std_err = linregress(x, y)
line = slope * x + intercept
ax.plot(x, line, color='r')

r_squared_9 = r_value ** 2
ax.text(0.05, 0.95, f"R-squared = {r_squared:.3f}", transform=ax.transAxes)

plt.show()

fig.savefig('Freedoms_2019.png', dpi=300, bbox_inches='tight')

# %%
average_rsquared = np.mean([r_squared_5, r_squared_6, r_squared_7, r_squared_8, r_squared_9])

# %%
average_rsquared
# Out:
# 0.3131728533057084

# %%
family_data_5 = fif_df['Generosity']

family_data_5 = fif_df['Generosity']
family_mean_5 = np.mean(family_data_5)
family_std_5 = np.std(family_data_5)
family_normal_5 = np.random.normal(family_mean_5, family_std_5, size=len(family_data_5))

fig, ax = plt.subplots()
ax.hist(family_data_5, bins=30, density=True, alpha=0.5, label="Generosity")
ax.plot(np.sort(family_normal_5), 1/(family_std_5 * np.sqrt(2 * np.pi)) *
        np.exp(-(np.sort(family_normal_5) - family_mean_5)**2 / (2 * family_std_5**2)), label="Normal Distribution")
ax.legend()
ax.set_title("Normal Distribution of Generosity 2015")
ax.set_xlabel("Generosity")
ax.set_ylabel("Density")

fig.savefig('Generosity_ND_2015.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
family_data_6 = six_df['Generosity']

family_data_6 = six_df['Generosity']
family_mean_6 = np.mean(family_data_6)
family_std_6 = np.std(family_data_6)
family_normal_6 = np.random.normal(family_mean_6, family_std_6, size=len(family_data_6))

fig, ax = plt.subplots()
ax.hist(family_data_6, bins=30, density=True, alpha=0.5, label="Generosity")
ax.plot(np.sort(family_normal_6), 1/(family_std_6 * np.sqrt(2 * np.pi)) *
        np.exp(-(np.sort(family_normal_6) - family_mean_6)**2 / (2 * family_std_6**2)), label="Normal Distribution")
ax.legend()
ax.set_title("Normal Distribution of Generosity 2016")
ax.set_xlabel("Generosity")
ax.set_ylabel("Density")

fig.savefig('Generosity_ND_2016.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
family_data_7 = sev_df['Generosity']

family_data_7 = sev_df['Generosity']
family_mean_7 = np.mean(family_data_7)
family_std_7 = np.std(family_data_7)
family_normal_7 = np.random.normal(family_mean_7, family_std_7, size=len(family_data_7))

fig, ax = plt.subplots()
ax.hist(family_data_7, bins=30, density=True, alpha=0.5, label="Generosity")
ax.plot(np.sort(family_normal_7), 1/(family_std_7 * np.sqrt(2 * np.pi)) *
        np.exp(-(np.sort(family_normal_7) - family_mean_7)**2 / (2 * family_std_7**2)), label="Normal Distribution")
ax.legend()
ax.set_title("Normal Distribution of Family Score 2017")
ax.set_xlabel("Generosity")
ax.set_ylabel("Density")

fig.savefig('Generosity_ND_2017.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
family_data_8 = eight_df['Generosity']

family_data_8 = eight_df['Generosity']
family_mean_8 = np.mean(family_data_7)
family_std_8 = np.std(family_data_7)
family_normal_8 = np.random.normal(family_mean_8, family_std_8, size=len(family_data_8))

fig, ax = plt.subplots()
ax.hist(family_data_8, bins=30, density=True, alpha=0.5, label="Generosity")
ax.plot(np.sort(family_normal_8), 1/(family_std_8 * np.sqrt(2 * np.pi)) *
        np.exp(-(np.sort(family_normal_8) - family_mean_8)**2 / (2 * family_std_8**2)), label="Normal Distribution")
ax.legend()
ax.set_title("Normal Distribution of Family Score 2018")
ax.set_xlabel("Generosity")
ax.set_ylabel("Density")

fig.savefig('Generosity_ND_2018.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
family_data_9 = nine_df['Generosity']

family_data_9 = nine_df['Generosity']
family_mean_9 = np.mean(family_data_7)
family_std_9 = np.std(family_data_7)
family_normal_9 = np.random.normal(family_mean_9, family_std_9, size=len(family_data_9))

fig, ax = plt.subplots()
ax.hist(family_data_9, bins=30, density=True, alpha=0.5, label="Generosity")
ax.plot(np.sort(family_normal_9), 1/(family_std_9 * np.sqrt(2 * np.pi)) *
        np.exp(-(np.sort(family_normal_9) - family_mean_9)**2 / (2 * family_std_9**2)), label="Normal Distribution")
ax.legend()
ax.set_title("Normal Distribution of Family Score 2019")
ax.set_xlabel("Generosity")
ax.set_ylabel("Density")

fig.savefig('Generosity_ND_2019.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
x = fif_df['Happiness Score']
y = fif_df['Generosity']

fig, ax = plt.subplots()

ax.scatter(x, y)

ax.set_title("Happiness Score and Generosity Relationship 2015")
ax.set_xlabel("Happiness Score")
ax.set_ylabel("Generosity")

slope, intercept, r_value, p_value, std_err = linregress(x, y)
line = slope * x + intercept
ax.plot(x, line, color='r')

r_squared_5 = r_value ** 2
ax.text(0.05, 0.95, f"R-squared = {r_squared:.3f}", transform=ax.transAxes)

plt.show()

fig.savefig('Generosity_2015.png', dpi=300, bbox_inches='tight')

# %%
x = six_df['Happiness Score']
y = six_df['Generosity']

fig, ax = plt.subplots()

ax.scatter(x, y)

ax.set_title("Happiness Score and Generosity Relationship 2016")
ax.set_xlabel("Happiness Score")
ax.set_ylabel("Generosity")

slope, intercept, r_value, p_value, std_err = linregress(x, y)
line = slope * x + intercept
ax.plot(x, line, color='r')

r_squared_6 = r_value ** 2
ax.text(0.05, 0.95, f"R-squared = {r_squared:.3f}", transform=ax.transAxes)

plt.show()

fig.savefig('Generosity_2016.png', dpi=300, bbox_inches='tight')

# %%
x = sev_df['Happiness.Score']
y = sev_df['Generosity']

fig, ax = plt.subplots()

ax.scatter(x, y)

ax.set_title("Happiness Score and Generosity Relationship 2017")
ax.set_xlabel("Happiness Score")
ax.set_ylabel("Generosity")

slope, intercept, r_value, p_value, std_err = linregress(x, y)
line = slope * x + intercept
ax.plot(x, line, color='r')

r_squared_7 = r_value ** 2
ax.text(0.05, 0.95, f"R-squared = {r_squared:.3f}", transform=ax.transAxes)

plt.show()

fig.savefig('Generosity_2017.png', dpi=300, bbox_inches='tight')

# %%
x = eight_df['Score']
y = eight_df['Generosity']

fig, ax = plt.subplots()

ax.scatter(x, y)

ax.set_title("Happiness Score and Generosity Relationship 2018")
ax.set_xlabel("Happiness Score")
ax.set_ylabel("Generosity")

slope, intercept, r_value, p_value, std_err = linregress(x, y)
line = slope * x + intercept
ax.plot(x, line, color='r')

r_squared_8 = r_value ** 2
ax.text(0.05, 0.95, f"R-squared = {r_squared:.3f}", transform=ax.transAxes)

plt.show()

fig.savefig('Generosity_2018.png', dpi=300, bbox_inches='tight')

# %%
x = nine_df['Score']
y = nine_df['Generosity']

fig, ax = plt.subplots()

ax.scatter(x, y)

ax.set_title("Happiness Score and Generosity Relationship 2019")
ax.set_xlabel("Happiness Score")
ax.set_ylabel("Generosity")

slope, intercept, r_value, p_value, std_err = linregress(x, y)
line = slope * x + intercept
ax.plot(x, line, color='r')

r_squared_9 = r_value ** 2
ax.text(0.05, 0.95, f"R-squared = {r_squared:.3f}", transform=ax.transAxes)

plt.show()

fig.savefig('Generosity_2019.png', dpi=300, bbox_inches='tight')
